# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 1,100)

f = 2*np.sqrt(x*(1-x))
plt.plot(x, f)

plt.grid()
plt.xticks(np.arange(0, 1.1, 0.1))
plt.yticks(np.arange(0, 1.1, 0.1))
plt.title("X/H = 2*sqrt(h/H*(1-h/H))")
plt.xlabel("h/H")
plt.ylabel("X/H")
plt.show()
